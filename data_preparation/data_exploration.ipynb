# %%
import pandas as pd

# %%
df = pd.read_csv('../Data/1980_title_publ_inventor/1980_title_publ_inventor.csv')
df
# Out:
#                                                title.en  \
# 0     A work table with a guard device for a motor-d...
# 1     Method and plant for collecting of oil floatin...
# 2     Skin treatment compositions, process for their...
# 3     Safety circuit for a potentially dangerous mac...
# 4                          Apparatus for wire stripping
# ...                                                 ...
# 6747  Liquid phase chemical process with separation ...
# 6748    Olefine polymerization catalyst and use thereof
# 6749             Single cell protein and its production
# 6750  Tri-iodoalkenyl esters of N-substituted carbam...
# 6751  Preparation of biphenol by the oxidative coupl...
#
#                                                inventor  publication.date  \
# 0     [{'name': 'Gjerde, Arne', 'country': 'NO', 'ci...          19800206
# 1     [{'name': 'Garin, Gert', 'country': 'SE', 'cit...          19800206
# ...

# %%
df_2 = pd.read_csv('../Data/1980_title_publ_inventor (1)/1980_title_publ_inventor.csv')
df_2
# Out:
#                                                title.en publication.country  \
# 0     Building elements and method of constructing a...                  EP
# 1     Esters of halogenated substituted cyclopropano...                  EP
# 2     Recognins, their chemoreciprocals, target atta...                  EP
# 3     Gem-bis (hydroxymethyl) alcohols and mixtures ...                  EP
# 4     Novel process for the manufacture of thiophene...                  EP
# ...                                                 ...                 ...
# 6747  Lubricating composition and method for making ...                  EP
# 6748  Deuterated isoflurane, its use as an anestheti...                  EP
# 6749  Novel branched-chain monoalcohols and derivati...                  EP
# 6750  Electrocatalyst, electrode comprising the elec...                  EP
# 6751  A perfumed synthetic resin product and a metho...                  EP
#
# ...
